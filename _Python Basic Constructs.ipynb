# %% [markdown]
# Q1. Using Python script as a calculator
# Create the variables n, r, p and assign them values 10, 5, and 100 respectively. Then evaluate the following expression in the Python console.
# 𝐴 = 𝑝 (1 + 𝑟/ 100)n
# a. 100
# b. 162.89
# c. 189
# d. None of the above

# %%
# Assign values to the variables
n = 10  # number of periods
r = 5   # interest rate
p = 100  # principal amount

# Calculating the amount A
A = p * (1 + r / 100) ** n

# Print the result
print("The value of A is:", A)
# Out:
# The value of A is: 162.8894626777442

# %% [markdown]
# Q2. In a given string format operation, how will you print the given string. A = 10
# B = 20
# Str = "There are {} students in the class, with {} who play at least one sport."
# a.	print(string.format(a,b))
# b.	print(string+a+b)
# c.	print(string.format(b,a))
# d.	None of the above

# %%
A = 10
B = 20
Str = "There are {} students in the class, with {} who play at least one sport."
print(Str.format(A, B))
# Out:
# There are 10 students in the class, with 20 who play at least one sport.

# %%
A = 10
B = 20
Str = f"There are {A} students in the class, with {B} who play at least one sport."
print(Str)
# Out:
# There are 10 students in the class, with 20 who play at least one sport.

# %% [markdown]
# Q3. In a given sample string, How do you print a double quoted string in between a regular
# string using the escape character?
# Sample output = It goes without saying, “Time is Money”, and none can deny it.
# a.	print(“It goes without saying, \“Time is Money\”, and none can deny it.”)
# b.	print(“It goes without saying, \Time is Money\, and none can deny it.”)
# c.	print(“It goes without saying” + “Time is Money” + “and none can deny it.”)
# d.	None of the above.

# %%
print("It goes without saying, \"Time is Money\", and none can deny it.")
# Out:
# It goes without saying, "Time is Money", and none can deny it.

# %% [markdown]
# Q4. What will be the output of the following code? x = lambda a,b: a//b
# x(10,3)
# a. 3.3333333333
# b. 3
# c. 30
# d. 1000

# %%
x = lambda a, b: a // b
print(x(10, 3))
# Out:
# 3

# %% [markdown]
# Q5. What will be the output of the following code? A = 10
# B = 12
# print("Smaller") if A == B else print("Greater") if A < B else print("True")
# a.	True
# b.	Smaller
# c.	Greater
# d.	None of the above

# %%
A = 10
B = 12

print("Smaller") if A == B else print("Greater") if A < B else print("True")
# Out:
# Greater

# %% [markdown]
# Q6. What will be the output of the following code?
# ![python image](attachment:34b62090-62cb-4093-8b49-e9372c5563a0.png)
#
#
#
# a. [2 7 3 5 4 6]
# b.	TypeError
# c.	NameError: name 'numpy' is not defined
# d.	None of the above

# %%
import numpy as np
my_list1 = [2, 7, 3, 5, 4, 6]
print(my_list1)
arr_1 = np.array([1, 2, 3, 4, 5, 6])
print(arr_1 + np.array(my_list1, dtype=int))
# Out:
# [2, 7, 3, 5, 4, 6]
# [ 3  9  6  9  9 12]

# %% [markdown]
# c.	NameError: name 'numpy' is not defined

# %% [markdown]
# Q7. Create a string called ‘string’ with the value as “Machine Learning”. Which code(s) is/are appropriate to slice the substring “Learn”?
#
# a.	string[slice(13,8,1)]
# b.	string[slice(1,8,1)]
# c.	string[8:14]
# d.	string[slice(8,13,1)]

# %%
string = "Machine Learning"
substring = string[8:13:1]  # "Learn"
print(substring)
# Out:
# Learn

# %% [markdown]
# d.	string[slice(8,13,1)]

# %% [markdown]
# Q8. Create a sequence of numbers from 10 to 25 and increment by 4. What is the index of the
# value 18?
#
# a.	3
# b.	2
# c.	0
# d.	1

# %%
# Create a sequence of numbers from 10 to 25 with an increment of 4
sequence = [i for i in range(10, 26, 4)]

# Find the index of the value 18
index_of_18 = sequence.index(18)

print("Sequence:", sequence)  # Output: [10, 14, 18, 22]
print("Index of 18:", index_of_18)  # Output: 2
# Out:
# Sequence: [10, 14, 18, 22]
# Index of 18: 2

# %% [markdown]
# Q9. Which of the following is true with respect to the below codes?
# ![python image](attachment:adfba8bc-af1d-4716-b2c0-8512172724c9.png)![image.png](attachment:f52c74f7-25ef-4533-be9c-b9418907f90f.png)
#
# a.	num1 = num2
# b.	num1 ≠ num2
# c.	num1 < num2
# d.	num1 > num2

# %%
num1 = 5**4          # Using the exponentiation operator
num2 = pow(5, 4)     # Using the built-in pow() function
print(num1, num2)
# Out:
# 625 625

# %% [markdown]
# a.	num1 = num2

# %% [markdown]
# Q10.A Python NameError exception is raised when: -
#
# a.	Trying to access a variable which has not been defined
# b.	Trying to access a key in a dictionary that does not exist
# c.	Accessing a column with misspelled column name
# d.	Accessing the function from a module that has not been imported

# %% [markdown]
# a. Trying to access a variable that has not been defined

# %%
Q11.What type of exception will be raised for the code given below?

a.	NameError
b.	KeyError
c.	ValueError
d.	AttributeError

# %%
x = "string" 
int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 x = "string"
# ----> 2 int(x)
#
# ValueError: invalid literal for int() with base 10: 'string'

# %% [markdown]
# Q12. FileNotFoundError exception is raised by operating system errors when: -
#
# a.	Trying to create a file or directory which already exists
# b.	A file or directory is requested but does not exist in the working directory
# c.	Trying to run an operation without the adequate access rights
# d.	A directory operation, os.listdir() is requested on something which is not a directory

# %% [markdown]
# b. A file or directory is requested but does not exist in the working directory.

# %%
Q13.Consider a variable Z. The value of Z is "ID-5632". Data type of Z is: -
a.	Complex
b.	Character
c.	Integer
d.	Boolean

# %%
Z = "ID-5632"
print(type(Z))  # Output: <class 'str'>
# Out:
# <class 'str'>

# %% [markdown]
# b.	Character

# %%
Which of the following variable(s) are character data type? 
a. K= “4”
b. J= “Welcome”
c. L= “?”
d. All of the above

# %%
# Define the variables
K = "4"
J = "Welcome"
L = "?"

# Check and print the data type of each variable
print(f"K is of type: {type(K)}")  # Output: <class 'str'>
print(f"J is of type: {type(J)}")  # Output: <class 'str'>
print(f"L is of type: {type(L)}")  # Output: <class 'str'>

# Check if all are character (string) types
all_are_strings = all(isinstance(var, str) for var in [K, J, L])
print("All variables are of character data type:", all_are_strings)
# Out:
# K is of type: <class 'str'>
# J is of type: <class 'str'>
# L is of type: <class 'str'>
# All variables are of character data type: True

# %% [markdown]
# .Choose the symbol/s that does not have the ability to convert any values to string?
# a.	( )
# b.	“ ”
# c.	{}
# d.	#

# %%
# Define the symbols
symbols = {
    "parentheses": "( )",
    "quotes": "\" \"",
    "curly_braces": "{}",
    "hash": "#"
}

# Check which symbols don't convert to string
non_convertible = [symbol for symbol in symbols if symbol in ["parentheses", "hash"]]

print("Symbols that do not convert any values to strings:", non_convertible)
# Out:
# Symbols that do not convert any values to strings: ['parentheses', 'hash']

# %% [markdown]
# a.	( ), c.	{}

# %% [markdown]
# Q16.Create a dictionary ‘Country’ that maps the following countries to their capitals respectively:
#
#
# Country	India	China	Japan	Qatar	France
# State	Delhi	Beijing	Tokyo	Doha	Marseilles
#
# Find 2 commands to replace “Marseilles” with “Paris” is:

# %%
# Creating the dictionary
Country = {
    "India": "Delhi",
    "China": "Beijing",
    "Japan": "Tokyo",
    "Qatar": "Doha",
    "France": "Marseilles"
}

# Replacing "Marseilles" with "Paris" using two different commands

# Command 1: Direct assignment
Country["France"] = "Paris"

# Command 2: Using the update() method
Country.update({"France": "Paris"})

# Output the updated dictionary
print(Country)
# Out:
# {'India': 'Delhi', 'China': 'Beijing', 'Japan': 'Tokyo', 'Qatar': 'Doha', 'France': 'Paris'}

# %% [markdown]
# Q17. Create the tuples given below tuple_1 = (1,5,6,7,8)
# tuple_2 = (8,9,4)
# Identify which of the following code does not work on a tuple.
#
# a.	sum(tuple_1)
# b.	len(tuple_2)
# c.	tuple_2 + tuple_1
# d.	tuple_1[3] = 45

# %%
# Creating the tuples
tuple_1 = (1, 5, 6, 7, 8)
tuple_2 = (8, 9, 4)

# Operations to test
results = {
    "a. sum(tuple_1)": sum(tuple_1),                      # Works: Sums the elements of tuple_1
    "b. len(tuple_2)": len(tuple_2),                      # Works: Returns the length of tuple_2
    "c. tuple_2 + tuple_1": tuple_2 + tuple_1,           # Works: Concatenates tuple_2 and tuple_1
    "d. tuple_1[3] = 45": "Error",                        # Does not work: Tuples are immutable
}

# Output the results of operations
for operation, result in results.items():
    print(f"{operation}: {result}")
# Out:
# a. sum(tuple_1): 27
# b. len(tuple_2): 3
# c. tuple_2 + tuple_1: (8, 9, 4, 1, 5, 6, 7, 8)
# d. tuple_1[3] = 45: Error

# %% [markdown]
# Q18. How many elements in the following data structure?
#
# s = {1,2,3,4,4,4,5,6}

# %%
# Define the set
s = {1, 2, 3, 4, 4, 4, 5, 6}

# Calculate the number of unique elements
num_elements = len(s)

# Output the result
print("Number of unique elements in the set:", num_elements)
# Out:
# Number of unique elements in the set: 6

# %% [markdown]
# Q19.Write a function which finds all pythagorean triplets of triangles whose sides are no greater than a natural number N.

# %%
def find_pythagorean_triplets(N):
    triplets = []
    for a in range(1, N+1):
        for b in range(a, N+1):  # Start b from a to avoid duplicates
            c = (a**2 + b**2)**0.5
            if c.is_integer() and c <= N:  # Check if c is a perfect square and within the limit
                triplets.append((a, b, int(c)))
    return triplets

# Example usage
N = 10
triplets = find_pythagorean_triplets(N)
print("Pythagorean triplets with sides no greater than", N, "are:", triplets)
# Out:
# Pythagorean triplets with sides no greater than 10 are: [(3, 4, 5), (6, 8, 10)]
